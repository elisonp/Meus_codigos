# %%
# Lendo o arquivo de dados
display(dbutils.fs.ls("/databricks-datasets"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/databricks-datasets/</td><td>databricks-datasets/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/COVID/</td><td>COVID/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/README.md</td><td>README.md</td><td>976</td><td>1532468253000</td></tr><tr><td>dbfs:/databricks-datasets/Rdatasets/</td><td>Rdatasets/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/SPARK_README.md</td><td>SPARK_README.md</td><td>3359</td><td>1455043490000</td></tr><tr><td>dbfs:/databricks-datasets/adult/</td><td>adult/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/airlines/</td><td>airlines/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/amazon/</td><td>amazon/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/asa/</td><td>asa/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/atlas_higgs/</td><td>atlas_higgs/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/bikeSharing/</td><td>bikeSharing/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/cctvVideos/</td><td>cctvVideos/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/credit-card-fraud/</td><td>credit-card-fraud/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/cs100/</td><td>cs100/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/cs110x/</td><td>cs110x/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/cs190/</td><td>cs190/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/data.gov/</td><td>data.gov/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/definitive-guide/</td><td>definitive-guide/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/delta-sharing/</td><td>delta-sharing/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/flights/</td><td>flights/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/flower_photos/</td><td>flower_photos/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/flowers/</td><td>flowers/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/genomics/</td><td>genomics/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/hail/</td><td>hail/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/identifying-campaign-effectiveness/</td><td>identifying-campaign-effectiveness/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/iot/</td><td>iot/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/iot-stream/</td><td>iot-stream/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/learning-spark/</td><td>learning-spark/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/learning-spark-v2/</td><td>learning-spark-v2/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/lending-club-loan-stats/</td><td>lending-club-loan-stats/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/med-images/</td><td>med-images/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/media/</td><td>media/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/mnist-digits/</td><td>mnist-digits/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/news20.binary/</td><td>news20.binary/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/nyctaxi/</td><td>nyctaxi/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/nyctaxi-with-zipcodes/</td><td>nyctaxi-with-zipcodes/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/online_retail/</td><td>online_retail/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/overlap-join/</td><td>overlap-join/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/power-plant/</td><td>power-plant/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/databri ...

# %%
# lendo o arquivo de dados
arquivo = "dbfs:/databricks-datasets/flights/"

# %%
# Lendo arquivo csv, com cabeçalho e o infraschema sendo definido pelo framework
# inferSchema: Define os tipo de dados para as colunas
df = spark \
.read.format("csv") \
.option("inferSchema","True")\
.option("header","True")\
.csv(arquivo)

# %%
# Imprime os datatypes das colunas do dataframe
df.printSchema()
# Out:
# root
#  |-- date: string (nullable = true)
#  |-- delay: string (nullable = true)
#  |-- distance: string (nullable = true)
#  |-- origin: string (nullable = true)
#  |-- destination: string (nullable = true)

# %%
# imprime o tipo da variável df
type(df)
# Out:
# Out[6]: pyspark.sql.dataframe.DataFrame

# %%
# Retorna as primeiras 5 linhas do dataframe em formato array
df.take(5)
# Out:
# Out[7]: [Row(date='01011245', delay='6', distance='602', origin='ABE', destination='ATL'),
#  Row(date='01020600', delay='-8', distance='369', origin='ABE', destination='DTW'),
#  Row(date='01021245', delay='-2', distance='602', origin='ABE', destination='ATL'),
#  Row(date='01020605', delay='-4', distance='602', origin='ABE', destination='ATL'),
#  Row(date='01031245', delay='-4', distance='602', origin='ABE', destination='ATL')]

# %%
# Imprime a quantidade de linhas no dataframe
df.count()
# Out:
# Out[8]: 1392106

# %%
# lendo o arquivo previamente com a opção InfraShema off
# Para isso, deverá passar o parâmetro schema e definir o tipo de dados para cada coluna que será trabalhado
df = spark \
.read.format("csv") \
.option("inferSchema","False")\
.option("header","True")\
.csv(arquivo)

# %%
from pyspark.sql.functions import max
df.select(max("delay")).take(1)
# Out:
# Out[11]: [Row(max(delay)='995')]

# %%
# Filtrando linhas de um dataframe usando filter
df.filter("delay<2").show(2)
# Out:
# +--------+-----+--------+------+-----------+
# |    date|delay|distance|origin|destination|
# +--------+-----+--------+------+-----------+
# |01020600|   -8|     369|   ABE|        DTW|
# |01021245|   -2|     602|   ABE|        ATL|
# +--------+-----+--------+------+-----------+
# only showing top 2 rows

# %%
# usando where (um alias para o metodo filter)
df.where("delay<2").show(2)
# Out:
# +--------+-----+--------+------+-----------+
# |    date|delay|distance|origin|destination|
# +--------+-----+--------+------+-----------+
# |01020600|   -8|     369|   ABE|        DTW|
# |01021245|   -2|     602|   ABE|        ATL|
# +--------+-----+--------+------+-----------+
# only showing top 2 rows

# %%
# Ordena o DataFrame pela coluna delay
df.sort("delay").show(5)
# Out:
# +--------------------+-----+--------+------+-----------+
# |                date|delay|distance|origin|destination|
# +--------------------+-----+--------+------+-----------+
# |Abbotsford\tBC\tC...| null|    null|  null|       null|
# |Aberdeen\tSD\tUSA...| null|    null|  null|       null|
# |Abilene\tTX\tUSA\...| null|    null|  null|       null|
# | Akron\tOH\tUSA\tCAK| null|    null|  null|       null|
# |Alamosa\tCO\tUSA\...| null|    null|  null|       null|
# +--------------------+-----+--------+------+-----------+
# only showing top 5 rows

# %%
# Ordenando a coluna delay na forma decrescente
from pyspark.sql.functions import asc,desc,expr

df.orderBy(expr("delay desc")).show(10)
# Out:
# +--------------------+-----+--------+------+-----------+
# |                date|delay|distance|origin|destination|
# +--------------------+-----+--------+------+-----------+
# |Abbotsford\tBC\tC...| null|    null|  null|       null|
# |Aberdeen\tSD\tUSA...| null|    null|  null|       null|
# |Abilene\tTX\tUSA\...| null|    null|  null|       null|
# | Akron\tOH\tUSA\tCAK| null|    null|  null|       null|
# |Alamosa\tCO\tUSA\...| null|    null|  null|       null|
# |Albany\tGA\tUSA\tABY| null|    null|  null|       null|
# |Albany\tNY\tUSA\tALB| null|    null|  null|       null|
# |Albuquerque\tNM\t...| null|    null|  null|       null|
# |Alexandria\tLA\tU...| null|    null|  null|       null|
# |Allentown\tPA\tUS...| null|    null|  null|       null|
# +--------------------+-----+--------+------+-----------+
# only showing top 10 rows

# %%
# visualizando estatísticas descritivas
df.describe().show()
# Out:
# +-------+--------------------+--------------------+--------------------+-------+-----------+
# |summary|                date|               delay|            distance| origin|destination|
# +-------+--------------------+--------------------+--------------------+-------+-----------+
# |  count|             1392106|             1391580|             1391579|1391578|    1391578|
# |   mean|   2180446.584000322|  12.079802928761449|   690.5508264718184|   null|       null|
# | stddev|   838031.1536741031|   38.80773374985648|    513.662815366331|   null|       null|
# |    min|"Cap-aux-Meules, ...| airline and rout...| dataset can be f...|    ABE|        ABE|
# |    max|  Yuma\tAZ\tUSA\tYUM|                 995|                 999|    YUM|        YUM|
# +-------+--------------------+--------------------+--------------------+-------+-----------+

# %%
# interando sobre todas as linhas do dataframe
for i in df.collect():
    print(i)
    print(i[0],i[1])
# Out:
# Row(date='01011245', delay='6', distance='602', origin='ABE', destination='ATL')
# 01011245 6
# Row(date='01020600', delay='-8', distance='369', origin='ABE', destination='DTW')
# 01020600 -8
# Row(date='01021245', delay='-2', distance='602', origin='ABE', destination='ATL')
# 01021245 -2
# Row(date='01020605', delay='-4', distance='602', origin='ABE', destination='ATL')
# 01020605 -4
# Row(date='01031245', delay='-4', distance='602', origin='ABE', destination='ATL')
# 01031245 -4
# Row(date='01030605', delay='0', distance='602', origin='ABE', destination='ATL')
# 01030605 0
# Row(date='01041243', delay='10', distance='602', origin='ABE', destination='ATL')
# 01041243 10
# Row(date='01040605', delay='28', distance='602', origin='ABE', destination='ATL')
# 01040605 28
# Row(date='01051245', delay='88', distance='602', origin='ABE', destination='ATL')
# 01051245 88
# Row(date='01050605', delay='9', distance='602', origin='ABE', destination='ATL')
# 01050605 9
# Row(date='01061215', delay='-6', distance='602', origin='ABE', destination='ATL')
# 01061215 -6
# Row(date='01061725', delay='69', distance='602', origin='ABE', destination='ATL')
# 01061725 69
# Row(date='01061230', delay='0', distance='369', origin='ABE', destination='DTW')
# 01061230 0
# Row(date='01060625', delay='-3', distance='602', origin='ABE', destination='ATL')
# 01060625 -3
# Row(date='01070600', delay='0', distance='369', origin='ABE', destination='DTW')
# 01070600 0
# Row(date='01071725', delay='0', distance='602', origin='ABE', destination='ATL')
# 01071725 0
# Row(date='01071230', delay='0', distance='369', origin='ABE', destination='DTW')
# 01071230 0
# Row(date='01070625', delay='0', distance='602', origin='ABE', destination='ATL')
# 01070625 0
# Row(date='01071219', delay='0', distance='569', origin='ABE', destination='ORD')
# 01071219 0
# Row(date='01080600', delay='0', distance='369', origin='ABE', destination='DTW')
# 01080600 0
# Row(date='01081230', delay='33', distance='369', origin='ABE', destination='DTW')
# 01081230 33
# Row(date='01080625', delay='1', distance='602', origin='ABE', destination='ATL')
# 01080625 1
# Row(date='01080607', delay='5', distance='569', origin='ABE', destination='ORD')
# 01080607 5
# Row(date='01081219', delay='54', distance='569', origin='ABE', destination='ORD')
# 01081219 54
# Row(date='01091215', delay='43', distance='602', origin='ABE', destination='ATL')
# 01091215 43
# Row(date='01090600', delay='151', distance='369', origin='ABE', destination='DTW')
# 01090600 151
# Row(date='01091725', delay='0', distance='602', origin='ABE', destination='ATL')
# 01091725 0
# Row(date='01091230', delay='-4', distance='369', origin='ABE', destination='DTW')
# 01091230 -4
# Row(date='01090625', delay='8', distance='602', origin='ABE', destination='ATL')
# 01090625 8
# Row(date='01091219', delay='83', distance='569', origin='ABE', destination='ORD')
# 01091219 83
# Row(date='01101215', delay='-5', distance='602', origin='ABE', destination='ATL')
# 01101215 -5
# Row(date='01100600', delay='-5', distance='369', origin='ABE', destination='DTW')
# 01100600 -5
# Row(date='01101725', delay='7', distance='602', origin='ABE', destination='ATL')
# 01101725 7
# Row(date='01101230', delay='-8', distance='369', origin='ABE', destination='DTW')
# 01101230 -8
# Row(date='01100625', delay='52', distance='602', origin='ABE', destination='ATL')
# 01100625 52
# Row(date='01101219', delay='0', distance='569', origin='ABE', destination='ORD')
# 01101219 0
# Row(date='01111215', delay='127', distance='602', origin='ABE', destination='ATL')
# 01111215 127
# Row(date='01110600', delay='-9', distance='369', origin='ABE', destination='DTW')
# 01110600 -9
# Row(date='01110625', delay='-4', distance='602', origin='ABE', destination='ATL')
# 01110625 -4
# Row(date='01121215', delay='-5', distance='602', origin='ABE', destination='ATL')
# 01121215 -5
# Row(date='01121725', delay='-1', distance='602', origin='ABE', destination='ATL')
# 01121725 -1
# Row(date='01131215', delay='14', distance='602', origin='ABE', destination='ATL')
# 01131215 14
# Row(date='01130600', delay='-7', distance='369', origin='ABE', destination='DTW')
# 01130600 -7
# Row(date='01131725', delay='-6', distance='602', origin='ABE', destination='ATL')
# 01131725 -6
# Row(date='01131230', delay='-13', distance='369', origin='ABE', destination='DTW')
# 01131230 -13
# Row(date='01130625', delay='29', distance='602', origin='ABE', destination='ATL')
# 01130625 29
# Row(date='01131219', delay='-8', distance='569', origin='ABE', destination='ORD')
# 01131219 -8
# Row(date='01140600', delay='-9', distance='369', origin='ABE', destination='DTW')
# 01140600 -9
# Row(date='01141725', delay='-9', distance='602', origin='ABE', destination='ATL')
# 01141725 -9
# Row(date='01141230', delay='-8', distance='369', origin='ABE', destination='DTW')
# 01141230 -8
# Row(date='01140625', delay='-5', distance='602', origin='ABE', destination='ATL')
# 01140625 -5
# Row(date='01141219', delay='-10', distance='569', origin='ABE', destination='ORD')
# 01141219 -10
# Row(date='01150600', delay='0', distance='369', origin='ABE', destination='DTW')
# 01150600 0
# Row(date='01151725', delay='-6', distance='602', origin='ABE', destination='ATL')
# 01151725 -6
# Row(date='01151230', delay='0', distance='369', origin='ABE', destination='DTW')
# 01151230 0
# Row(date='01150625', delay='0', distance='602', origin='ABE', destination='ATL')
# 01150625 0
# Row(date='01150607', delay='0', distance='569', origin='ABE', destination='ORD')
# 01150607 0
# Row(date='01151219', delay='0', distance='569', origin='ABE', destination='ORD')
# 01151219 0
# Row(date='01161215', delay='-10', distance='602', origin='ABE', destination='ATL')
# 01161215 -10
# Row(date='01160600', delay='-1', distance='369', origin='ABE', destination='DTW')
# 01160600 -1
# Row(date='01161725', delay='-6', distance='602', origin='ABE', destination='ATL')
# 01161725 -6
# Row(date='01161230', delay='-7', distance='369', origin='ABE', destination='DTW')
# 01161230 -7
# Row(date='01160625', delay='-4', distance='602', origin='ABE', destination='ATL')
# 01160625 -4
# Row(date='01161219', delay='68', distance='569', origin='ABE', destination='ORD')
# 01161219 68
# Row(date='01171215', delay='-8', distance='602', origin='ABE', destination='ATL')
# 01171215 -8
# Row(date='01170600', delay='-5', distance='369', origin='ABE', destination='DTW')
# 01170600 -5
# Row(date='01171725', delay='5', distance='602', origin='ABE', destination='ATL')
# 01171725 5
# Row(date='01171230', delay='-10', distance='369', origin='ABE', destination='DTW')
# 01171230 -10
# Row(date='01170625', delay='-6', distance='602', origin='ABE', destination='ATL')
# 01170625 -6
# Row(date='01171219', delay='-10', distance='569', origin='ABE', destination='ORD')
# 01171219 -10
# Row(date='01181215', delay='-12', distance='602', origin='ABE', destination='ATL')
# 01181215 -12
# Row(date='01180600', delay='-13', distance='369', origin='ABE', destination='DTW')
# 01180600 -13
# Row(date='01180625', delay='0', distance='602', origin='ABE', destination='ATL')
# 01180625 0
# Row(date='01191215', delay='-16', distance='602', origin='ABE', destination='ATL')
# 01191215 -16
# Row(date='01191725', delay='-5', distance='602', origin='ABE', destination='ATL')
# 01191725 -5
# Row(date='01201215', delay='-8', distance='602', origin='ABE', destination='ATL')
# 01201215 -8
# Row(date='01201725', delay='-5', distance='602', origin='ABE', destination='ATL')
# 01201725 -5
# Row(date='01201230', delay='-11', distance='369', origin='ABE', destination='DTW')
# 01201230 -11
# Row(date='01200625', delay='-7', distance='602', origin='ABE', destination='ATL')
# 01200625 -7
# Row(date='01201219', delay='-6', distance='569', origin='ABE', destination='ORD')
# 01201219 -6
# Row(date='01210600', delay='89', distance='369', origin='ABE', destination='DTW')
# 01210600 89
# Row(date='01211725', delay='0', distance='602', origin='ABE', destination='ATL')
# 01211725 0
# Row(date='01211230', delay='44', distance='369', origin='ABE', destination='DTW')
# 01211230 44
# Row(date='01210625', delay='-6', distance='602', origin='ABE', destination='ATL')
# 01210625 -6
# Row(date='01211219', delay='9', distance='569', origin='ABE', destination='ORD')
# 01211219 9
# Row(date='01220600', delay='80', distance='369', origin='ABE', destination='DTW')
# 01220600 80
# Row(date='01221230', delay='-5', distance='369', origin='ABE', destination='DTW')
# 01221230 -5
# Row(date='01220625', delay='333', distance='602', origin='ABE', destination='ATL')
# 01220625 333
# Row(date='01220607', delay='219', distance='569', origin='ABE', destination='ORD')
# 01220607 219
# Row(date='01221219', delay='15', distance='569', origin='ABE', destination='ORD')
# 01221219 15
# Row(date='01231215', delay='-12', distance='602', origin='ABE', destination='ATL')
# 01231215 -12
# Row(date='01230600', delay='-3', distance='369', origin='ABE', destination='DTW')
# 01230600 -3
# Row(date='01231725', delay='180', distance='602', origin='ABE', destination='ATL')
# 01231725 180
# Row(date='01231230', delay='-5', distance='369', origin='ABE', destination='DTW')
# 01231230 -5
# Row(date='01230625', delay='-8', distance='602', origin='ABE', destination='ATL')
# 01230625 -8
# Row(date='01231219', delay='-13', distance='569', origin='ABE', destination='ORD')
# 01231219 -13
# Row(date='01241215', delay='-11', distance='602', origin='ABE', destination='ATL')
# 01241215 -11
# Row(date='01240600', delay='-3', distance='369', origin='ABE', destination='DTW')
# 01240600 -3
# Row(date='01241725', delay='2', distance='602', origin='ABE', destination='ATL')
# 01241725 2
# Row(date='01241230', delay='-5', distance='369', origin='ABE', destination='DTW')
# 01241230 -5
# Row(date='01240625', delay='-3', distance='602', origin='ABE', destination='ATL')
# 01240625 -3
# Row(date='01241219', delay='0', distance='569', origin='ABE', destination='ORD')
# 01241219 0
# Row(date='01251215', delay='2', distance='602', origin='ABE', destination='ATL')
# 01251215 2
# Row(date='01250600', delay='-4', distance='369', origin='ABE', destination='DTW')
# 01250600 -4
# Row(date='01250625', delay='-4', distance='602', origin='ABE', destination='ATL')
# 01250625 -4
# Row(date='01261215', delay='1', distance='602', origin='ABE', destination='ATL')
# 01261215 1
# Row(date='01261725', delay='7', distance='602', origin='ABE', destination='ATL')
# 01261725 7
# Row(date='01271215', delay='-4', distance='602', origin='ABE', destination='ATL')
# 01271215 -4
# Row(date='01270600', delay='-9', distance='369', origin='ABE', destination='DTW')
# 01270600 -9
# Row(date='01271725', delay='-8', distance='602', origin='ABE', destination='ATL')
# 01271725 -8
# Row(date='01271230', delay='-7', distance='369', origin='ABE', destination='DTW')
# 01271230 -7
# Row(date='01270625', delay='-1', distance='602', origin='ABE', destination='ATL')
# 01270625 -1
# Row(date='01271219', delay='0', distance='569', origin='ABE', destination='ORD')
# 01271219 0
# Row(date='01280600', delay='-6', distance='369', origin='ABE', destination='DTW')
# 01280600 -6
# Row(date='01281725', delay='-3', distance='602', origin='ABE', destination='ATL')
# 01281725 -3
# Row(date='01281230', delay='-8', distance='369', origin='ABE', destination='DTW')
# 01281230 -8
# Row(date='01280625', delay='-4', distance='602', origin='ABE', destination='ATL')
# 01280625 -4
# Row(date='01281219', delay='0', distance='569', origin='ABE', destination='ORD')
# 01281219 0
# Row(date='01290600', delay='0', distance='369', origin='ABE', destination='DTW')
# 01290600 0
# Row(date='01291230', delay='0', distance='369', origin='ABE', destination='DTW')
# 01291230 0
# Row(date='01290625', delay='4', distance='602', origin='ABE', destination='ATL')
# 01290625 4
# Row(date='01290607', delay='92', distance='569', origin='ABE', destination='ORD')
# 01290607 92
# Row(date='01291219', delay='-10', distance='569', origin='ABE', destination='ORD')
# 01291219 -10
# Row(date='01301215', delay='0', distance='602', origin='ABE', destination='ATL')
# 01301215 0
# Row(date='01300600', delay='-1', distance='369', origin='ABE', destination='DTW')
# 01300600 -1
# Row(date='01301725', delay='10', distance='602', origin='ABE', destination='ATL')
# 01301725 10
# Row(date='01301230', delay='0', distance='369', origin='ABE', destination='DTW')
# 01301230 0
# Row(date='01300625', delay='0', distance='602', origin='ABE', destination='ATL')
# 01300625 0
# Row(date='01301219', delay='-11', distance='569', origin='ABE', destination='ORD')
# 01301219 -11
# Row(date='01311215', delay='1', distance='602', origin='ABE', destination='ATL')
# 01311215 1
# Row(date='01310600', delay='-4', distance='369', origin='ABE', destination='DTW')
# 01310600 -4
# Row(date='01311725', delay='25', distance='602', origin='ABE', destination='ATL')
# 01311725 25
# Row(date='01311230', delay='-4', distance='369', origin='ABE', destination='DTW')
# 01311230 -4
# Row(date='01310625', delay='-5', distance='602', origin='ABE', destination='ATL')
# 01310625 -5
# Row(date='01311219', delay='24', distance='569', origin='ABE', destination='ORD')
# 01311219 24
# Row(date='01011400', delay='26', distance='137', origin='ABI', destination='DFW')
# 01011400 26
# Row(date='01011525', delay='-11', distance='137', origin='ABI', destination='DFW')
# 01011525 -11
# Row(date='01021400', delay='-5', distance='137', origin='ABI', destination='DFW')
# 01021400 -5
# Row(date='01021525', delay='47', distance='137', origin='ABI', destination='DFW')
# 01021525 47
# Row(date='01031400', delay='-12', distance='137', origin='ABI', destination='DFW')
# 01031400 -12
# Row(date='01031525', delay='40', distance='137', origin='ABI', destination='DFW')
# 01031525 40
# Row(date='01041400', delay='-12', distance='137', origin='ABI', destination='DFW')
# 01041400 -12
# Row(date='01041525', delay='3', distance='137', origin='ABI', destination='DFW')
# 01041525 3
# Row(date='01051400', delay='-5', distance='137', origin='ABI', destination='DFW')
# 01051400 -5
# Row(date='01051525', delay='-5', distance='137', origin='ABI', destination='DFW')
# 01051525 -5
# Row(date='01061400', delay='2', distance='137', origin='ABI', destination='DFW')
# 01061400 2
# Row(date='01061525', delay='22', distance='137', origin='ABI', destination='DFW')
# 01061525 22
# Row(date='01071400', delay='-12', distance='137', origin='ABI', destination='DFW')
# 01071400 -12
# Row(date='01071525', delay='-15', distance='137', origin='ABI', destination='DFW')
# 01071525 -15
# Row(date='01081525', delay='21', distance='137', origin='ABI', destination='DFW')
# 01081525 21
# Row(date='01091525', delay='-8', distance='137', origin='ABI', destination='DFW')
# 01091525 -8
# Row(date='01101525', delay='4', distance='137', origin='ABI', destination='DFW')
# 01101525 4
# Row(date='01111525', delay='-23', distance='137', origin='ABI', destination='DFW')
# 01111525 -23
# Row(date='01121525', delay='-9', distance='137', origin='ABI', destination='DFW')
# 01121525 -9
# Row(date='01131525', delay='-12', distance='137', origin='ABI', destination='DFW')
# 01131525 -12
# Row(date='01141525', delay='-5', distance='137', origin='ABI', destination='DFW')
# 01141525 -5
# Row(date='01151525', delay='-17', distance='137', origin='ABI', destination='DFW')
# 01151525 -17
# Row(date='01161525', delay='2', distance='137', origin='ABI', destination='DFW')
# 01161525 2
# Row(date='01171525', delay='-9', distance='137', origin='ABI', destination='DFW')
# 01171525 -9
# Row(date='01181525', delay='-5', distance='137', origin='ABI', destination='DFW')
# 01181525 -5
# Row(date='01191525', delay='-3', distance='137', origin='ABI', destination='DFW')
# 01191525 -3
# Row(date='01201525', delay='-6', distance='137', origin='ABI', destination='DFW')
# 01201525 -6
# Row(date='01211525', delay='-17', distance='137', origin='ABI', destination='DFW')
# 01211525 -17
# Row(date='01221525', delay='40', distance='137', origin='ABI', destination='DFW')
# 01221525 40
# Row(date='01231525', delay='-12', distance='137', origin='ABI', destination='DFW')
# 01231525 -12
# Row(date='01241525', delay='21', distance='137', origin='ABI', destination='DFW')
# 01241525 21
# Row(date='01251525', delay='-6', distance='137', origin='ABI', destination='DFW')
# 01251525 -6
# Row(date='01261525', delay='-12', distance='137', origin='ABI', destination='DFW')
# 01261525 -12
# Row(date='01271525', delay='-13', distance='137', origin='ABI', destination='DFW')
# 01271525 -13
# Row(date='01281525', delay='-10', distance='137', origin='ABI', destination='DFW')
# 01281525 -10
# Row(date='01291525', delay='146', distance='137', origin='ABI', destination='DFW')
# 01291525 146
# Row(date='01301525', delay='-13', distance='137', origin='ABI', destination='DFW')
# 01301525 -13
# Row(date='01311525', delay='6', distance='137', origin='ABI', destination='DFW')
# 01311525 6
# Row(date='01010925', delay='-9', distance='137', origin='ABI', destination='DFW')
# 01010925 -9
# Row(date='01011730', delay='72', distance='137', origin='ABI', destination='DFW')
# 01011730 72
# Row(date='01010700', delay='-5', distance='137', origin='ABI', destination='DFW')
# 01010700 -5
# Row(date='01011155', delay='-6', distance='137', origin='ABI', destination='DFW')
# 01011155 -6
# Row(date='01010810', delay='62', distance='137', origin='ABI', destination='DFW')
# 01010810 62
# Row(date='01020550', delay='-7', distance='137', origin='ABI', destination='DFW')
# 01020550 -7
# Row(date='01020925', delay='7', distance='137', origin='ABI', destination='DFW')
# 01020925 7
# Row(date='01021730', delay='27', distance='137', origin='ABI', destination='DFW')
# 01021730 27
# Row(date='01020700', delay='150', distance='137', origin='ABI', destination='DFW')
# 01020700 150
# Row(date='01021155', delay='0', distance='137', origin='ABI', destination='DFW')
# 01021155 0
# Row(date='01020810', delay='1', distance='137', origin='ABI', destination='DFW')
# 01020810 1
# Row(date='01030550', delay='51', distance='137', origin='ABI', destination='DFW')
# 01030550 51
# Row(date='01030925', delay='-7', distance='137', origin='ABI', destination='DFW')
# 01030925 -7
# Row(date='01031730', delay='-18', distance='137', origin='ABI', destination='DFW')
# 01031730 -18
# Row(date='01030700', delay='2', distance='137', origin='ABI', destination='DFW')
# 01030700 2
# Row(date='01031155', delay='48', distance='137', origin='ABI', destination='DFW')
# 01031155 48
# Row(date='01030810', delay='-3', distance='137', origin='ABI', destination='DFW')
# 01030810 -3
# Row(date='01040925', delay='-7', distance='137', origin='ABI', destination='DFW')
# 01040925 -7
# Row(date='01041730', delay='135', distance='137', origin='ABI', destination='DFW')
# 01041730 135
# Row(date='01040700', delay='-3', distance='137', origin='ABI', destination='DFW')
# 01040700 -3
# Row(date='01041155', delay='-2', distance='137', origin='ABI', destination='DFW')
# 01041155 -2
# Row(date='01040810', delay='-12', distance='137', origin='ABI', destination='DFW')
# 01040810 -12
# Row(date='01050550', delay='-8', distance='137', origin='ABI', destination='DFW')
# 01050550 -8
# Row(date='01050925', delay='-10', distance='137', origin='ABI', destination='DFW')
# 01050925 -10
# Row(date='01051730', delay='-2', distance='137', origin='ABI', destination='DFW')
# 01051730 -2
# Row(date='01050700', delay='-6', distance='137', origin='ABI', destination='DFW')
# 01050700 -6
# Row(date='01051155', delay='-2', distance='137', origin='ABI', destination='DFW')
# 01051155 -2
# Row(date='01050810', delay='-12', distance='137', origin='ABI', destination='DFW')
# 01050810 -12
# Row(date='01060550', delay='-8', distance='137', origin='ABI', destination='DFW')
# 01060550 -8
# Row(date='01060925', delay='0', distance='137', origin='ABI', destination='DFW')
# 01060925 0
# Row(date='01061730', delay='-7', distance='137', origin='ABI', destination='DFW')
# 01061730 -7
# Row(date='01060700', delay='-3', distance='137', origin='ABI', destination='DFW')
# 01060700 -3
# Row(date='01061155', delay='-4', distance='137', origin='ABI', destination='DFW')
# 01061155 -4
# Row(date='01060810', delay='-8', distance='137', origin='ABI', destination='DFW')
# 01060810 -8
# Row(date='01070550', delay='-3', distance='137', origin='ABI', destination='DFW')
# 01070550 -3
# Row(date='01070925', delay='62', distance='137', origin='ABI', destination='DFW')
# 01070925 62
# Row(date='01071730', delay='0', distance='137', origin='ABI', destination='DFW')
# 01071730 0
# Row(date='01070700', delay='4', distance='137', origin='ABI', destination='DFW')
# 01070700 4
# Row(date='01071155', delay='10', distance='137', origin='ABI', destination='DFW')
# 01071155 10
# Row(date='01070810', delay='-10', distance='137', origin='ABI', destination='DFW')
# 01070810 -10
# Row(date='01080550', delay='-9', distance='137', origin='ABI', destination='DFW')
# 01080550 -9
# Row(date='01080925', delay='-11', distance='137', origin='ABI', destination='DFW')
# 01080925 -11
# Row(date='01081730', delay='7', distance='137', origin='ABI', destination='DFW')
# 01081730 7
# Row(date='01080700', delay='-8', distance='137', origin='ABI', destination='DFW')
# 01080700 -8
# Row(date='01081155', delay='-11', distance='137', origin='ABI', destination='DFW')
# 01081155 -11
# Row(date='01080810', delay='-13', distance='137', origin='ABI', destination='DFW')
# 01080810 -13
# Row(date='01081400', delay='10', distance='137', origin='ABI', destination='DFW')
# 01081400 10
# Row(date='01090550', delay='395', distance='137', origin='ABI', destination='DFW')
# 01090550 395
# Row(date='01090925', delay='0', distance='137', origin='ABI', destination='DFW')
# 01090925 0
# Row(date='01091730', delay='38', distance='137', origin='ABI', destination='DFW')
# 01091730 38
# Row(date='01090700', delay='6', distance='137', origin='ABI', destination='DFW')
# 01090700 6
# Row(date='01091155', delay='21', distance='137', origin='ABI', destination='DFW')
# 01091155 21
# Row(date='01090810', delay='16', distance='137', origin='ABI', destination='DFW')
# 01090810 16
# Row(date='01091400', delay='-6', distance='137', origin='ABI', destination='DFW')
# 01091400 -6
# Row(date='01100550', delay='-4', distance='137', origin='ABI', destination='DFW')
# 01100550 -4
# Row(date='01100925', delay='34', distance='137', origin='ABI', destination='DFW')
# 01100925 34
# Row(date='01101730', delay='-2', distance='137', origin='ABI', destination='DFW')
# 01101730 -2
# Row(date='01100700', delay='129', distance='137', origin='ABI', destination='DFW')
# 01100700 129
# Row(date='01101155', delay='-1', distance='137', origin='ABI', destination='DFW')
# 01101155 -1
# Row(date='01100810', delay='-11', distance='137', origin='ABI', destination='DFW')
# 01100810 -11
# Row(date='01101400', delay='30', distance='137', origin='ABI', destination='DFW')
# 01101400 30
# Row(date='01110905', delay='-8', distance='137', origin='ABI', destination='DFW')
# 01110905 -8
# Row(date='01111730', delay='-14', distance='137', origin='ABI', destination='DFW')
# 01111730 -14
# Row(date='01110700', delay='-5', distance='137', origin='ABI', destination='DFW')
# 01110700 -5
# Row(date='01111155', delay='16', distance='137', origin='ABI', destination='DFW')
# 01111155 16
# Row(date='01110810', delay='-6', distance='137', origin='ABI', destination='DFW')
# 01110810 -6
# Row(date='01111400', delay='39', distance='137', origin='ABI', destination='DFW')
# 01111400 39
# Row(date='01120550', delay='-12', distance='137', origin='ABI', destination='DFW')
# 01120550 -12
# Row(date='01120925', delay='-5', distance='137', origin='ABI', destination='DFW')
# 01120925 -5
# Row(date='01121730', delay='-9', distance='137', origin='ABI', destination='DFW')
# 01121730 -9
# Row(date='01120700', delay='35', distance='137', origin='ABI', destination='DFW')
# 01120700 35
# Row(date='01121155', delay='158', distance='137', origin='ABI', destination='DFW')
# 01121155 158
# Row(date='01120810', delay='-9', distance='137', origin='ABI', destination='DFW')
# 01120810 -9
# Row(date='01121400', delay='-9', distance='137', origin='ABI', destination='DFW')
# 01121400 -9
# Row(date='01130550', delay='-5', distance='137', origin='ABI', destination='DFW')
# 01130550 -5
# Row(date='01130925', delay='-7', distance='137', origin='ABI', destination='DFW')
# 01130925 -7
# Row(date='01131730', delay='-9', distance='137', origin='ABI', destination='DFW')
# 01131730 -9
# Row(date='01130700', delay='-9', distance='137', origin='ABI', destination='DFW')
# 01130700 -9
# Row(date='01131155', delay='-10', distance='137', origin='ABI', destination='DFW')
# 01131155 -10
# Row(date='01130810', delay='-7', distance='137', origin='ABI', destination='DFW')
# 01130810 -7
# Row(date='01131400', delay='-1', distance='137', origin='ABI', destination='DFW')
# 01131400 -1
# Row(date='01140550', delay='0', distance='137', origin='ABI', destination='DFW')
# 01140550 0
# Row(date='01140925', delay='4', distance='137', origin='ABI', destination='DFW')
# 01140925 4
# Row(date='01141730', delay='-13', distance='137', origin='ABI', destination='DFW')
# 01141730 -13
# Row(date='01140700', delay='49', distance='137', origin='ABI', destination='DFW')
# 01140700 49
# Row(date='01141155', delay='-10', distance='137', origin='ABI', destination='DFW')
# 01141155 -10
# Row(date='01140810', delay='-8', distance='137', origin='ABI', destination='DFW')
# 01140810 -8
# Row(date='01141400', delay='-17', distance='137', origin='ABI', destination='DFW')
# 01141400 -17
# Row(date='01150550', delay='-11', distance='137', origin='ABI', destination='DFW')
# 01150550 -11
# Row(date='01150925', delay='-6', distance='137', origin='ABI', destination='DFW')
# 01150925 -6
# Row(date='01151730', delay='-9', distance='137', origin='ABI', destination='DFW')
# 01151730 -9
# Row(date='01150700', delay='-8', distance='137', origin='ABI', destination='DFW')
# 01150700 -8
# Row(date='01151155', delay='-5', distance='137', origin='ABI', destination='DFW')
# 01151155 -
#
# *** WARNING: max output size exceeded, skipping output. ***
#
# (date='New Orleans\tLA\tUSA\tMSY', delay=None, distance=None, origin=None, destination=None)
# New Orleans	LA	USA	MSY None
# Row(date='New York\tNY\tUSA\tJFK', delay=None, distance=None, origin=None, destination=None)
# New York	NY	USA	JFK None
# Row(date='New York\tNY\tUSA\tNYC', delay=None, distance=None, origin=None, destination=None)
# New York	NY	USA	NYC None
# Row(date='New York\tNY\tUSA\tLGA', delay=None, distance=None, origin=None, destination=None)
# New York	NY	USA	LGA None
# Row(date='Newark\tNJ\tUSA\tEWR', delay=None, distance=None, origin=None, destination=None)
# Newark	NJ	USA	EWR None
# Row(date='Newburgh\tNY\tUSA\tSWF', delay=None, distance=None, origin=None, destination=None)
# Newburgh	NY	USA	SWF None
# Row(date='Newport News\tVA\tUSA\tPHF', delay=None, distance=None, origin=None, destination=None)
# Newport News	VA	USA	PHF None
# Row(date='Nome\tAK\tUSA\tOME', delay=None, distance=None, origin=None, destination=None)
# Nome	AK	USA	OME None
# Row(date='Norfolk\tVA\tUSA\tORF', delay=None, distance=None, origin=None, destination=None)
# Norfolk	VA	USA	ORF None
# Row(date='North Bay\tON\tCanada\tYYB', delay=None, distance=None, origin=None, destination=None)
# North Bay	ON	Canada	YYB None
# Row(date='North Bend\tOR\tUSA\tOTH', delay=None, distance=None, origin=None, destination=None)
# North Bend	OR	USA	OTH None
# Row(date='North Platte\tNE\tUSA\tLBF', delay=None, distance=None, origin=None, destination=None)
# North Platte	NE	USA	LBF None
# Row(date='Oakland\tCA\tUSA\tOAK', delay=None, distance=None, origin=None, destination=None)
# Oakland	CA	USA	OAK None
# Row(date='Ogdensburg\tNY\tUSA\tOGS', delay=None, distance=None, origin=None, destination=None)
# Ogdensburg	NY	USA	OGS None
# Row(date='Oklahoma City\tOK\tUSA\tOKC', delay=None, distance=None, origin=None, destination=None)
# Oklahoma City	OK	USA	OKC None
# Row(date='Omaha\tNE\tUSA\tOMA', delay=None, distance=None, origin=None, destination=None)
# Omaha	NE	USA	OMA None
# Row(date='Ontario\tCA\tUSA\tONT', delay=None, distance=None, origin=None, destination=None)
# Ontario	CA	USA	ONT None
# Row(date='Orange County\tCA\tUSA\tSNA', delay=None, distance=None, origin=None, destination=None)
# Orange County	CA	USA	SNA None
# Row(date='Orlando\tFL\tUSA\tMCO', delay=None, distance=None, origin=None, destination=None)
# Orlando	FL	USA	MCO None
# Row(date='Oshkosh\tWI\tUSA\tOSH', delay=None, distance=None, origin=None, destination=None)
# Oshkosh	WI	USA	OSH None
# Row(date='Ottawa\tON\tCanada\tYOW', delay=None, distance=None, origin=None, destination=None)
# Ottawa	ON	Canada	YOW None
# Row(date='Owensboro\tKY\tUSA\tOWB', delay=None, distance=None, origin=None, destination=None)
# Owensboro	KY	USA	OWB None
# Row(date='Oxnard\tCA\tUSA\tOXR', delay=None, distance=None, origin=None, destination=None)
# Oxnard	CA	USA	OXR None
# Row(date='Paducah\tKY\tUSA\tPAH', delay=None, distance=None, origin=None, destination=None)
# Paducah	KY	USA	PAH None
# Row(date='Page\tAZ\tUSA\tPGA', delay=None, distance=None, origin=None, destination=None)
# Page	AZ	USA	PGA None
# Row(date='Palm Springs\tCA\tUSA\tPSP', delay=None, distance=None, origin=None, destination=None)
# Palm Springs	CA	USA	PSP None
# Row(date='Panama City\tFL\tUSA\tPFN', delay=None, distance=None, origin=None, destination=None)
# Panama City	FL	USA	PFN None
# Row(date='Parkersburg\tWV\tUSA\tPKB', delay=None, distance=None, origin=None, destination=None)
# Parkersburg	WV	USA	PKB None
# Row(date='Pasco\tWA\tUSA\tPSC', delay=None, distance=None, origin=None, destination=None)
# Pasco	WA	USA	PSC None
# Row(date='Pellston\tMI\tUSA\tPLN', delay=None, distance=None, origin=None, destination=None)
# Pellston	MI	USA	PLN None
# Row(date='Pendleton\tOR\tUSA\tPDT', delay=None, distance=None, origin=None, destination=None)
# Pendleton	OR	USA	PDT None
# Row(date='Pensacola\tFL\tUSA\tPNS', delay=None, distance=None, origin=None, destination=None)
# Pensacola	FL	USA	PNS None
# Row(date='Penticton\tBC\tCanada\tYYF', delay=None, distance=None, origin=None, destination=None)
# Penticton	BC	Canada	YYF None
# Row(date='Peoria\tIL\tUSA\tPIA', delay=None, distance=None, origin=None, destination=None)
# Peoria	IL	USA	PIA None
# Row(date='Philadelphia\tPA\tUSA\tPHL', delay=None, distance=None, origin=None, destination=None)
# Philadelphia	PA	USA	PHL None
# Row(date='Phoenix\tAZ\tUSA\tPHX', delay=None, distance=None, origin=None, destination=None)
# Phoenix	AZ	USA	PHX None
# Row(date='Pierre\tSD\tUSA\tPIR', delay=None, distance=None, origin=None, destination=None)
# Pierre	SD	USA	PIR None
# Row(date='Pinehurst\tNC\tUSA\tSOP', delay=None, distance=None, origin=None, destination=None)
# Pinehurst	NC	USA	SOP None
# Row(date='Pittsburgh\tPA\tUSA\tPIT', delay=None, distance=None, origin=None, destination=None)
# Pittsburgh	PA	USA	PIT None
# Row(date='Pocatello\tID\tUSA\tPIH', delay=None, distance=None, origin=None, destination=None)
# Pocatello	ID	USA	PIH None
# Row(date='Ponca City\tOK\tUSA\tPNC', delay=None, distance=None, origin=None, destination=None)
# Ponca City	OK	USA	PNC None
# Row(date='Port Hardy\tBC\tCanada\tYZT', delay=None, distance=None, origin=None, destination=None)
# Port Hardy	BC	Canada	YZT None
# Row(date='Portland\tME\tUSA\tPWM', delay=None, distance=None, origin=None, destination=None)
# Portland	ME	USA	PWM None
# Row(date='Portland\tOR\tUSA\tPDX', delay=None, distance=None, origin=None, destination=None)
# Portland	OR	USA	PDX None
# Row(date='Portsmouth\tNH\tUSA\tPSM', delay=None, distance=None, origin=None, destination=None)
# Portsmouth	NH	USA	PSM None
# Row(date='Powell River\tBC\tCanada\tYPW', delay=None, distance=None, origin=None, destination=None)
# Powell River	BC	Canada	YPW None
# Row(date='Prescott\tAZ\tUSA\tPRC', delay=None, distance=None, origin=None, destination=None)
# Prescott	AZ	USA	PRC None
# Row(date='Presque Isle\tME\tUSA\tPQI', delay=None, distance=None, origin=None, destination=None)
# Presque Isle	ME	USA	PQI None
# Row(date='Prince George\tBC\tCanada\tYXS', delay=None, distance=None, origin=None, destination=None)
# Prince George	BC	Canada	YXS None
# Row(date='Prince Rupert\tBC\tCanada\tYPR', delay=None, distance=None, origin=None, destination=None)
# Prince Rupert	BC	Canada	YPR None
# Row(date='Providence\tRI\tUSA\tPVD', delay=None, distance=None, origin=None, destination=None)
# Providence	RI	USA	PVD None
# Row(date='Provincetown\tMA\tUSA\tPVC', delay=None, distance=None, origin=None, destination=None)
# Provincetown	MA	USA	PVC None
# Row(date='Pueblo\tCO\tUSA\tPUB', delay=None, distance=None, origin=None, destination=None)
# Pueblo	CO	USA	PUB None
# Row(date='Pullman\tWA\tUSA\tPUW', delay=None, distance=None, origin=None, destination=None)
# Pullman	WA	USA	PUW None
# Row(date='Quebec\tPQ\tCanada\tYQB', delay=None, distance=None, origin=None, destination=None)
# Quebec	PQ	Canada	YQB None
# Row(date='Quesnel\tBC\tCanada\tYQZ', delay=None, distance=None, origin=None, destination=None)
# Quesnel	BC	Canada	YQZ None
# Row(date='Quincy\tIL\tUSA\tUIN', delay=None, distance=None, origin=None, destination=None)
# Quincy	IL	USA	UIN None
# Row(date='Raleigh\tNC\tUSA\tRDU', delay=None, distance=None, origin=None, destination=None)
# Raleigh	NC	USA	RDU None
# Row(date='Rankin Inlet\tNWT\tCanada\tYRT', delay=None, distance=None, origin=None, destination=None)
# Rankin Inlet	NWT	Canada	YRT None
# Row(date='Rapid City\tSD\tUSA\tRAP', delay=None, distance=None, origin=None, destination=None)
# Rapid City	SD	USA	RAP None
# Row(date='Red Lake\tON\tCanada\tYRL', delay=None, distance=None, origin=None, destination=None)
# Red Lake	ON	Canada	YRL None
# Row(date='Redding\tCA\tUSA\tRDD', delay=None, distance=None, origin=None, destination=None)
# Redding	CA	USA	RDD None
# Row(date='Redmond\tOR\tUSA\tRDM', delay=None, distance=None, origin=None, destination=None)
# Redmond	OR	USA	RDM None
# Row(date='Regina\tSK\tCanada\tYQR', delay=None, distance=None, origin=None, destination=None)
# Regina	SK	Canada	YQR None
# Row(date='Reno\tNV\tUSA\tRNO', delay=None, distance=None, origin=None, destination=None)
# Reno	NV	USA	RNO None
# Row(date='Rhinelander\tWI\tUSA\tRHI', delay=None, distance=None, origin=None, destination=None)
# Rhinelander	WI	USA	RHI None
# Row(date='Richmond\tVA\tUSA\tRIC', delay=None, distance=None, origin=None, destination=None)
# Richmond	VA	USA	RIC None
# Row(date='Riverton\tWY\tUSA\tRIW', delay=None, distance=None, origin=None, destination=None)
# Riverton	WY	USA	RIW None
# Row(date='Roanoke\tVA\tUSA\tROA', delay=None, distance=None, origin=None, destination=None)
# Roanoke	VA	USA	ROA None
# Row(date='Roberval\tPQ\tCanada\tYRJ', delay=None, distance=None, origin=None, destination=None)
# Roberval	PQ	Canada	YRJ None
# Row(date='Rochester\tMN\tUSA\tRST', delay=None, distance=None, origin=None, destination=None)
# Rochester	MN	USA	RST None
# Row(date='Rochester\tNY\tUSA\tROC', delay=None, distance=None, origin=None, destination=None)
# Rochester	NY	USA	ROC None
# Row(date='Rock Springs\tWY\tUSA\tRKS', delay=None, distance=None, origin=None, destination=None)
# Rock Springs	WY	USA	RKS None
# Row(date='Rockford\tIL\tUSA\tRFD', delay=None, distance=None, origin=None, destination=None)
# Rockford	IL	USA	RFD None
# Row(date='Rockland\tME\tUSA\tRKD', delay=None, distance=None, origin=None, destination=None)
# Rockland	ME	USA	RKD None
# Row(date='Roswell\tNM\tUSA\tROW', delay=None, distance=None, origin=None, destination=None)
# Roswell	NM	USA	ROW None
# Row(date='Rouyn-Noranda\tPQ\tCanada\tYUY', delay=None, distance=None, origin=None, destination=None)
# Rouyn-Noranda	PQ	Canada	YUY None
# Row(date='Rutland\tVT\tUSA\tRUT', delay=None, distance=None, origin=None, destination=None)
# Rutland	VT	USA	RUT None
# Row(date='Sacramento\tCA\tUSA\tSMF', delay=None, distance=None, origin=None, destination=None)
# Sacramento	CA	USA	SMF None
# Row(date='Saginaw\tMI\tUSA\tMBS', delay=None, distance=None, origin=None, destination=None)
# Saginaw	MI	USA	MBS None
# Row(date='Saint John\tNB\tCanada\tYSJ', delay=None, distance=None, origin=None, destination=None)
# Saint John	NB	Canada	YSJ None
# Row(date='Salina\tKS\tUSA\tSLN', delay=None, distance=None, origin=None, destination=None)
# Salina	KS	USA	SLN None
# Row(date='Salisbury\tMD\tUSA\tSBY', delay=None, distance=None, origin=None, destination=None)
# Salisbury	MD	USA	SBY None
# Row(date='Salt Lake City\tUT\tUSA\tSLC', delay=None, distance=None, origin=None, destination=None)
# Salt Lake City	UT	USA	SLC None
# Row(date='San Angelo\tTX\tUSA\tSJT', delay=None, distance=None, origin=None, destination=None)
# San Angelo	TX	USA	SJT None
# Row(date='San Antonio\tTX\tUSA\tSAT', delay=None, distance=None, origin=None, destination=None)
# San Antonio	TX	USA	SAT None
# Row(date='San Diego\tCA\tUSA\tSAN', delay=None, distance=None, origin=None, destination=None)
# San Diego	CA	USA	SAN None
# Row(date='San Francisco\tCA\tUSA\tQSF', delay=None, distance=None, origin=None, destination=None)
# San Francisco	CA	USA	QSF None
# Row(date='San Francisco\tCA\tUSA\tSFO', delay=None, distance=None, origin=None, destination=None)
# San Francisco	CA	USA	SFO None
# Row(date='San Jose\tCA\tUSA\tSJC', delay=None, distance=None, origin=None, destination=None)
# San Jose	CA	USA	SJC None
# Row(date='San Luis Obispo\tCA\tUSA\tSBP', delay=None, distance=None, origin=None, destination=None)
# San Luis Obispo	CA	USA	SBP None
# Row(date='Sand Point\tAK\tUSA\tSDP', delay=None, distance=None, origin=None, destination=None)
# Sand Point	AK	USA	SDP None
# Row(date='"Sandspit, Queen Charlotte Islands"\tBC\tCanada\tYZP', delay=None, distance=None, origin=None, destination=None)
# "Sandspit, Queen Charlotte Islands"	BC	Canada	YZP None
# Row(date='Santa Barbara\tCA\tUSA\tSBA', delay=None, distance=None, origin=None, destination=None)
# Santa Barbara	CA	USA	SBA None
# Row(date='Santa Fe\tNM\tUSA\tSAF', delay=None, distance=None, origin=None, destination=None)
# Santa Fe	NM	USA	SAF None
# Row(date='Santa Maria\tCA\tUSA\tSMX', delay=None, distance=None, origin=None, destination=None)
# Santa Maria	CA	USA	SMX None
# Row(date='Santa Rosa\tCA\tUSA\tSTS', delay=None, distance=None, origin=None, destination=None)
# Santa Rosa	CA	USA	STS None
# Row(date='Saranac Lake\tNY\tUSA\tSLK', delay=None, distance=None, origin=None, destination=None)
# Saranac Lake	NY	USA	SLK None
# Row(date='Sarasota\tFL\tUSA\tSRQ', delay=None, distance=None, origin=None, destination=None)
# Sarasota	FL	USA	SRQ None
# Row(date='Sarnia\tON\tCanada\tYZR', delay=None, distance=None, origin=None, destination=None)
# Sarnia	ON	Canada	YZR None
# Row(date='Saskatoon\tSK\tCanada\tYXE', delay=None, distance=None, origin=None, destination=None)
# Saskatoon	SK	Canada	YXE None
# Row(date='Sault Ste. Marie\tMI\tUSA\tCIU', delay=None, distance=None, origin=None, destination=None)
# Sault Ste. Marie	MI	USA	CIU None
# Row(date='Sault Ste. Marie\tON\tCanada\tYAM', delay=None, distance=None, origin=None, destination=None)
# Sault Ste. Marie	ON	Canada	YAM None
# Row(date='Savannah\tGA\tUSA\tSAV', delay=None, distance=None, origin=None, destination=None)
# Savannah	GA	USA	SAV None
# Row(date='Scottsbluff\tNE\tUSA\tBFF', delay=None, distance=None, origin=None, destination=None)
# Scottsbluff	NE	USA	BFF None
# Row(date='Seattle\tWA\tUSA\tSEA', delay=None, distance=None, origin=None, destination=None)
# Seattle	WA	USA	SEA None
# Row(date='Sept-Iles\tPQ\tCanada\tYZV', delay=None, distance=None, origin=None, destination=None)
# Sept-Iles	PQ	Canada	YZV None
# Row(date='Shenandoah Valley Airport\tVA\tUSA\tSHD', delay=None, distance=None, origin=None, destination=None)
# Shenandoah Valley Airport	VA	USA	SHD None
# Row(date='Sheridan\tWY\tUSA\tSHR', delay=None, distance=None, origin=None, destination=None)
# Sheridan	WY	USA	SHR None
# Row(date='Shreveport\tLA\tUSA\tSHV', delay=None, distance=None, origin=None, destination=None)
# Shreveport	LA	USA	SHV None
# Row(date='Sidney\tMT\tUSA\tSDY', delay=None, distance=None, origin=None, destination=None)
# Sidney	MT	USA	SDY None
# Row(date='Silver City\tNM\tUSA\tSVC', delay=None, distance=None, origin=None, destination=None)
# Silver City	NM	USA	SVC None
# Row(date='Sioux City\tIA\tUSA\tSUX', delay=None, distance=None, origin=None, destination=None)
# Sioux City	IA	USA	SUX None
# Row(date='Sioux Falls\tSD\tUSA\tFSD', delay=None, distance=None, origin=None, destination=None)
# Sioux Falls	SD	USA	FSD None
# Row(date='Sioux Lookout\tON\tCanada\tYXL', delay=None, distance=None, origin=None, destination=None)
# Sioux Lookout	ON	Canada	YXL None
# Row(date='Sitka\tAK\tUSA\tSIT', delay=None, distance=None, origin=None, destination=None)
# Sitka	AK	USA	SIT None
# Row(date='Skagway\tAK\tUSA\tSGY', delay=None, distance=None, origin=None, destination=None)
# Skagway	AK	USA	SGY None
# Row(date='Smithers\tBC\tCanada\tYYD', delay=None, distance=None, origin=None, destination=None)
# Smithers	BC	Canada	YYD None
# Row(date='South Bend\tIN\tUSA\tSBN', delay=None, distance=None, origin=None, destination=None)
# South Bend	IN	USA	SBN None
# Row(date='Spokane\tWA\tUSA\tGEG', delay=None, distance=None, origin=None, destination=None)
# Spokane	WA	USA	GEG None
# Row(date='Springfield\tIL\tUSA\tSPI', delay=None, distance=None, origin=None, destination=None)
# Springfield	IL	USA	SPI None
# Row(date='Springfield\tMA\tUSA\tCEF', delay=None, distance=None, origin=None, destination=None)
# Springfield	MA	USA	CEF None
# Row(date='Springfield\tMO\tUSA\tSGF', delay=None, distance=None, origin=None, destination=None)
# Springfield	MO	USA	SGF None
# Row(date='Springfield\tVT\tUSA\tVSF', delay=None, distance=None, origin=None, destination=None)
# Springfield	VT	USA	VSF None
# Row(date='St. Cloud\tMN\tUSA\tSTC', delay=None, distance=None, origin=None, destination=None)
# St. Cloud	MN	USA	STC None
# Row(date='St. George\tUT\tUSA\tSGU', delay=None, distance=None, origin=None, destination=None)
# St. George	UT	USA	SGU None
# Row(date="St. John's\tNF\tCanada\tYYT", delay=None, distance=None, origin=None, destination=None)
# St. John's	NF	Canada	YYT None
# Row(date='St. Louis\tMO\tUSA\tSTL', delay=None, distance=None, origin=None, destination=None)
# St. Louis	MO	USA	STL None
# Row(date='St. Petersburg\tFL\tUSA\tPIE', delay=None, distance=None, origin=None, destination=None)
# St. Petersburg	FL	USA	PIE None
# Row(date='State College\tPA\tUSA\tSCE', delay=None, distance=None, origin=None, destination=None)
# State College	PA	USA	SCE None
# Row(date='Steamboat Springs\tCO\tUSA\tSBS', delay=None, distance=None, origin=None, destination=None)
# Steamboat Springs	CO	USA	SBS None
# Row(date='Sudbury\tON\tCanada\tYSB', delay=None, distance=None, origin=None, destination=None)
# Sudbury	ON	Canada	YSB None
# Row(date='Sun Valley\tID\tUSA\tSUN', delay=None, distance=None, origin=None, destination=None)
# Sun Valley	ID	USA	SUN None
# Row(date='"Sydney, Cape Breton Island"\tNS\tCanada\tYQY', delay=None, distance=None, origin=None, destination=None)
# "Sydney, Cape Breton Island"	NS	Canada	YQY None
# Row(date='Syracuse\tNY\tUSA\tSYR', delay=None, distance=None, origin=None, destination=None)
# Syracuse	NY	USA	SYR None
# Row(date='Tallahassee\tFL\tUSA\tTLH', delay=None, distance=None, origin=None, destination=None)
# Tallahassee	FL	USA	TLH None
# Row(date='Tampa\tFL\tUSA\tTPA', delay=None, distance=None, origin=None, destination=None)
# Tampa	FL	USA	TPA None
# Row(date='Telluride\tCO\tUSA\tTEX', delay=None, distance=None, origin=None, destination=None)
# Telluride	CO	USA	TEX None
# Row(date='Terrace\tBC\tCanada\tYXT', delay=None, distance=None, origin=None, destination=None)
# Terrace	BC	Canada	YXT None
# Row(date='Texarkana\tAR\tUSA\tTXK', delay=None, distance=None, origin=None, destination=None)
# Texarkana	AR	USA	TXK None
# Row(date='Thief River Falls\tMN\tUSA\tTVF', delay=None, distance=None, origin=None, destination=None)
# Thief River Falls	MN	USA	TVF None
# Row(date='Thompson\tMB\tCanada\tYTH', delay=None, distance=None, origin=None, destination=None)
# Thompson	MB	Canada	YTH None
# Row(date='Thunder Bay\tON\tCanada\tYQT', delay=None, distance=None, origin=None, destination=None)
# Thunder Bay	ON	Canada	YQT None
# Row(date='Timmins\tON\tCanada\tYTS', delay=None, distance=None, origin=None, destination=None)
# Timmins	ON	Canada	YTS None
# Row(date='Toksook Bay\tAK\tUSA\tOOK', delay=None, distance=None, origin=None, destination=None)
# Toksook Bay	AK	USA	OOK None
# Row(date='Toledo\tOH\tUSA\tTOL', delay=None, distance=None, origin=None, destination=None)
# Toledo	OH	USA	TOL None
# Row(date='Eureka\tKS\tUSA\tTOP', delay=None, distance=None, origin=None, destination=None)
# Eureka	KS	USA	TOP None
# Row(date='Toronto\tON\tCanada\tYYZ', delay=None, distance=None, origin=None, destination=None)
# Toronto	ON	Canada	YYZ None
# Row(date='Toronto\tON\tCanada\tYTZ', delay=None, distance=None, origin=None, destination=None)
# Toronto	ON	Canada	YTZ None
# Row(date='Toronto\tON\tCanada\tYTO', delay=None, distance=None, origin=None, destination=None)
# Toronto	ON	Canada	YTO None
# Row(date='Traverse City\tMI\tUSA\tTVC', delay=None, distance=None, origin=None, destination=None)
# Traverse City	MI	USA	TVC None
# Row(date='Trenton\tNJ\tUSA\tTTN', delay=None, distance=None, origin=None, destination=None)
# Trenton	NJ	USA	TTN None
# Row(date='Tri-City Airport\tTN\tUSA\tTRI', delay=None, distance=None, origin=None, destination=None)
# Tri-City Airport	TN	USA	TRI None
# Row(date='Tucson\tAZ\tUSA\tTUS', delay=None, distance=None, origin=None, destination=None)
# Tucson	AZ	USA	TUS None
# Row(date='Tulsa\tOK\tUSA\tTUL', delay=None, distance=None, origin=None, destination=None)
# Tulsa	OK	USA	TUL None
# Row(date='Tupelo\tMS\tUSA\tTUP', delay=None, distance=None, origin=None, destination=None)
# Tupelo	MS	USA	TUP None
# Row(date='Twin Falls\tID\tUSA\tTWF', delay=None, distance=None, origin=None, destination=None)
# Twin Falls	ID	USA	TWF None
# Row(date='Tyler\tTX\tUSA\tTYR', delay=None, distance=None, origin=None, destination=None)
# Tyler	TX	USA	TYR None
# Row(date='Unalakleet\tAK\tUSA\tUNK', delay=None, distance=None, origin=None, destination=None)
# Unalakleet	AK	USA	UNK None
# Row(date='Vail\tCO\tUSA\tEGE', delay=None, distance=None, origin=None, destination=None)
# Vail	CO	USA	EGE None
# Row(date="Val-d'Or\tPQ\tCanada\tYVO", delay=None, distance=None, origin=None, destination=None)
# Val-d'Or	PQ	Canada	YVO None
# Row(date='Valdez\tAK\tUSA\tVDZ', delay=None, distance=None, origin=None, destination=None)
# Valdez	AK	USA	VDZ None
# Row(date='Valdosta\tGA\tUSA\tVLD', delay=None, distance=None, origin=None, destination=None)
# Valdosta	GA	USA	VLD None
# Row(date='Vancouver\tBC\tCanada\tYVR', delay=None, distance=None, origin=None, destination=None)
# Vancouver	BC	Canada	YVR None
# Row(date='Victoria\tBC\tCanada\tYYJ', delay=None, distance=None, origin=None, destination=None)
# Victoria	BC	Canada	YYJ None
# Row(date='Victoria\tTX\tUSA\tVCT', delay=None, distance=None, origin=None, destination=None)
# Victoria	TX	USA	VCT None
# Row(date='Visalia\tCA\tUSA\tVIS', delay=None, distance=None, origin=None, destination=None)
# Visalia	CA	USA	VIS None
# Row(date='"Wabush, Labrador"\tNF\tCanada\tYWK', delay=None, distance=None, origin=None, destination=None)
# "Wabush, Labrador"	NF	Canada	YWK None
# Row(date='Waco\tTX\tUSA\tACT', delay=None, distance=None, origin=None, destination=None)
# Waco	TX	USA	ACT None
# Row(date='Walla Walla\tWA\tUSA\tALW', delay=None, distance=None, origin=None, destination=None)
# Walla Walla	WA	USA	ALW None
# Row(date='Washington DC\t\tUSA\tIAD', delay=None, distance=None, origin=None, destination=None)
# Washington DC		USA	IAD None
# Row(date='Washington DC\t\tUSA\tDCA', delay=None, distance=None, origin=None, destination=None)
# Washington DC		USA	DCA None
# Row(date='Washington DC\t\tUSA\tWAS', delay=None, distance=None, origin=None, destination=None)
# Washington DC		USA	WAS None
# Row(date='Waterloo\tIA\tUSA\tALO', delay=None, distance=None, origin=None, destination=None)
# Waterloo	IA	USA	ALO None
# Row(date='Watertown\tNY\tUSA\tART', delay=None, distance=None, origin=None, destination=None)
# Watertown	NY	USA	ART None
# Row(date='Watertown\tSD\tUSA\tATY', delay=None, distance=None, origin=None, destination=None)
# Watertown	SD	USA	ATY None
# Row(date='Wausau\tWI\tUSA\tCWA', delay=None, distance=None, origin=None, destination=None)
# Wausau	WI	USA	CWA None
# Row(date='Wenatchee\tWA\tUSA\tEAT', delay=None, distance=None, origin=None, destination=None)
# Wenatchee	WA	USA	EAT None
# Row(date='West Palm Beach\tFL\tUSA\tPBI', delay=None, distance=None, origin=None, destination=None)
# West Palm Beach	FL	USA	PBI None
# Row(date='West Yellowstone\tMT\tUSA\tWYS', delay=None, distance=None, origin=None, destination=None)
# West Yellowstone	MT	USA	WYS None
# Row(date='White Plains\tNY\tUSA\tHPN', delay=None, distance=None, origin=None, destination=None)
# White Plains	NY	USA	HPN None
# Row(date='Whitehorse\tYT\tCanada\tYXY', delay=None, distance=None, origin=None, destination=None)
# Whitehorse	YT	Canada	YXY None
# Row(date='Wichita Falls\tTX\tUSA\tSPS', delay=None, distance=None, origin=None, destination=None)
# Wichita Falls	TX	USA	SPS None
# Row(date='Wichita\tKS\tUSA\tICT', delay=None, distance=None, origin=None, destination=None)
# Wichita	KS	USA	ICT None
# Row(date='Wilkes-Barre\tPA\tUSA\tAVP', delay=None, distance=None, origin=None, destination=None)
# Wilkes-Barre	PA	USA	AVP None
# Row(date='Williams Lake\tBC\tCanada\tYWL', delay=None, distance=None, origin=None, destination=None)
# Williams Lake	BC	Canada	YWL None
# Row(date='Williamsport\tPA\tUSA\tIPT', delay=None, distance=None, origin=None, destination=None)
# Williamsport	PA	USA	IPT None
# Row(date='Williston\tND\tUSA\tISN', delay=None, distance=None, origin=None, destination=None)
# Williston	ND	USA	ISN None
# Row(date='Wilmington\tDE\tUSA\tILG', delay=None, distance=None, origin=None, destination=None)
# Wilmington	DE	USA	ILG None
# Row(date='Wilmington\tNC\tUSA\tILM', delay=None, distance=None, origin=None, destination=None)
# Wilmington	NC	USA	ILM None
# Row(date='Windsor\tON\tCanada\tYQG', delay=None, distance=None, origin=None, destination=None)
# Windsor	ON	Canada	YQG None
# Row(date='Winnipeg\tMB\tCanada\tYWG', delay=None, distance=None, origin=None, destination=None)
# Winnipeg	MB	Canada	YWG None
# Row(date='Wolf Point\tMT\tUSA\tOLF', delay=None, distance=None, origin=None, destination=None)
# Wolf Point	MT	USA	OLF None
# Row(date='Worland\tWY\tUSA\tWRL', delay=None, distance=None, origin=None, destination=None)
# Worland	WY	USA	WRL None
# Row(date='Wrangell\tAK\tUSA\tWRG', delay=None, distance=None, origin=None, destination=None)
# Wrangell	AK	USA	WRG None
# Row(date='Yakima\tWA\tUSA\tYKM', delay=None, distance=None, origin=None, destination=None)
# Yakima	WA	USA	YKM None
# Row(date='Yakutat\tAK\tUSA\tYAK', delay=None, distance=None, origin=None, destination=None)
# Yakutat	AK	USA	YAK None
# Row(date='Yellowknife\tNWT\tCanada\tYZF', delay=None, distance=None, origin=None, destination=None)
# Yellowknife	NWT	Canada	YZF None
# Row(date='Yuma\tAZ\tUSA\tYUM', delay=None, distance=None, origin=None, destination=None)
# Yuma	AZ	USA	YUM None
# Row(date='The source `airports` dataset can be found at [OpenFlights Airport', delay=' airline and route data](http://openflights.org/data.html). ', distance=None, origin=None, destination=None)
# The source `airports` dataset can be found at [OpenFlights Airport  airline and route data](http://openflights.org/data.html).
# Row(date='The `flights`', delay=' also known as the `departuredelays`', distance=' dataset can be found at [Airline On-Time Performance and Causes of Flight Delays: On_Time Data](https://catalog.data.gov/dataset/airline-on-time-performance-and-causes-of-flight-delays-on-time-data)', origin=None, destination=None)
# The `flights`  also known as the `departuredelays`

# %%
# Adicionando uma coluna ao dataframe
df = df.withColumn('Nova Coluna',df['delay']+2)
df.show(10)
# Out:
# +--------+-----+--------+------+-----------+-----------+
# |    date|delay|distance|origin|destination|Nova Coluna|
# +--------+-----+--------+------+-----------+-----------+
# |01011245|    6|     602|   ABE|        ATL|        8.0|
# |01020600|   -8|     369|   ABE|        DTW|       -6.0|
# |01021245|   -2|     602|   ABE|        ATL|        0.0|
# |01020605|   -4|     602|   ABE|        ATL|       -2.0|
# |01031245|   -4|     602|   ABE|        ATL|       -2.0|
# |01030605|    0|     602|   ABE|        ATL|        2.0|
# |01041243|   10|     602|   ABE|        ATL|       12.0|
# |01040605|   28|     602|   ABE|        ATL|       30.0|
# |01051245|   88|     602|   ABE|        ATL|       90.0|
# |01050605|    9|     602|   ABE|        ATL|       11.0|
# +--------+-----+--------+------+-----------+-----------+
# only showing top 10 rows

# %%
# Renomeando uma coluna no dataframe
df.withColumnRenamed('Nova Coluna','New Column').show()
# Out:
# +--------+-----+--------+------+-----------+
# |    date|delay|distance|origin|destination|
# +--------+-----+--------+------+-----------+
# |01011245|    6|     602|   ABE|        ATL|
# |01020600|   -8|     369|   ABE|        DTW|
# |01021245|   -2|     602|   ABE|        ATL|
# |01020605|   -4|     602|   ABE|        ATL|
# |01031245|   -4|     602|   ABE|        ATL|
# |01030605|    0|     602|   ABE|        ATL|
# |01041243|   10|     602|   ABE|        ATL|
# |01040605|   28|     602|   ABE|        ATL|
# |01051245|   88|     602|   ABE|        ATL|
# |01050605|    9|     602|   ABE|        ATL|
# +--------+-----+--------+------+-----------+
# only showing top 10 rows

# %%
# Remove coluna
df = df.drop('Nova Coluna')
df.show(10)
# Out:
# +--------+-----+--------+------+-----------+----------+
# |    date|delay|distance|origin|destination|New Column|
# +--------+-----+--------+------+-----------+----------+
# |01011245|    6|     602|   ABE|        ATL|       8.0|
# |01020600|   -8|     369|   ABE|        DTW|      -6.0|
# |01021245|   -2|     602|   ABE|        ATL|       0.0|
# |01020605|   -4|     602|   ABE|        ATL|      -2.0|
# |01031245|   -4|     602|   ABE|        ATL|      -2.0|
# |01030605|    0|     602|   ABE|        ATL|       2.0|
# |01041243|   10|     602|   ABE|        ATL|      12.0|
# |01040605|   28|     602|   ABE|        ATL|      30.0|
# |01051245|   88|     602|   ABE|        ATL|      90.0|
# |01050605|    9|     602|   ABE|        ATL|      11.0|
# |01061215|   -6|     602|   ABE|        ATL|      -4.0|
# |01061725|   69|     602|   ABE|        ATL|      71.0|
# |01061230|    0|     369|   ABE|        DTW|       2.0|
# |01060625|   -3|     602|   ABE|        ATL|      -1.0|
# |01070600|    0|     369|   ABE|        DTW|       2.0|
# |01071725|    0|     602|   ABE|        ATL|       2.0|
# |01071230|    0|     369|   ABE|        DTW|       2.0|
# |01070625|    0|     602|   ABE|        ATL|       2.0|
# |01071219|    0|     569|   ABE|        ORD|       2.0|
# |01080600|    0|     369|   ABE|        DTW|       2.0|
# +--------+-----+--------+------+-----------+----------+
# only showing top 20 rows

# %%
df.filter("delay is NULL").show()
# Out:
# +--------------------+-----+--------+------+-----------+-----------+
# |                date|delay|distance|origin|destination|Nova Coluna|
# +--------------------+-----+--------+------+-----------+-----------+
# |Abbotsford\tBC\tC...| null|    null|  null|       null|       null|
# |Aberdeen\tSD\tUSA...| null|    null|  null|       null|       null|
# |Abilene\tTX\tUSA\...| null|    null|  null|       null|       null|
# | Akron\tOH\tUSA\tCAK| null|    null|  null|       null|       null|
# |Alamosa\tCO\tUSA\...| null|    null|  null|       null|       null|
# |Albany\tGA\tUSA\tABY| null|    null|  null|       null|       null|
# |Albany\tNY\tUSA\tALB| null|    null|  null|       null|       null|
# |Albuquerque\tNM\t...| null|    null|  null|       null|       null|
# |Alexandria\tLA\tU...| null|    null|  null|       null|       null|
# |Allentown\tPA\tUS...| null|    null|  null|       null|       null|
# |Alliance\tNE\tUSA...| null|    null|  null|       null|       null|
# |Alpena\tMI\tUSA\tAPN| null|    null|  null|       null|       null|
# |Altoona\tPA\tUSA\...| null|    null|  null|       null|       null|
# |Amarillo\tTX\tUSA...| null|    null|  null|       null|       null|
# |Anahim Lake\tBC\t...| null|    null|  null|       null|       null|
# |Anchorage\tAK\tUS...| null|    null|  null|       null|       null|
# |Appleton\tWI\tUSA...| null|    null|  null|       null|       null|
# |Arviat\tNWT\tCana...| null|    null|  null|       null|       null|
# |Asheville\tNC\tUS...| null|    null|  null|       null|       null|
# | Aspen\tCO\tUSA\tASE| null|    null|  null|       null|       null|
# +--------------------+-----+--------+------+-----------+-----------+
# only showing top 20 rows

# %%
df.filter(df.delay.isNull()).show(10)
# Out:
# +--------------------+-----+--------+------+-----------+-----------+
# |                date|delay|distance|origin|destination|Nova Coluna|
# +--------------------+-----+--------+------+-----------+-----------+
# |Abbotsford\tBC\tC...| null|    null|  null|       null|       null|
# |Aberdeen\tSD\tUSA...| null|    null|  null|       null|       null|
# |Abilene\tTX\tUSA\...| null|    null|  null|       null|       null|
# | Akron\tOH\tUSA\tCAK| null|    null|  null|       null|       null|
# |Alamosa\tCO\tUSA\...| null|    null|  null|       null|       null|
# |Albany\tGA\tUSA\tABY| null|    null|  null|       null|       null|
# |Albany\tNY\tUSA\tALB| null|    null|  null|       null|       null|
# |Albuquerque\tNM\t...| null|    null|  null|       null|       null|
# |Alexandria\tLA\tU...| null|    null|  null|       null|       null|
# |Allentown\tPA\tUS...| null|    null|  null|       null|       null|
# +--------------------+-----+--------+------+-----------+-----------+
# only showing top 10 rows

# %%
# Preenchendo os dados missing com valor 0
df.na.fill(value=0).show()
# df.na.fill("").show()
# Out:
# +--------+-----+--------+------+-----------+-----------+
# |    date|delay|distance|origin|destination|Nova Coluna|
# +--------+-----+--------+------+-----------+-----------+
# |01011245|    6|     602|   ABE|        ATL|        8.0|
# |01020600|   -8|     369|   ABE|        DTW|       -6.0|
# |01021245|   -2|     602|   ABE|        ATL|        0.0|
# |01020605|   -4|     602|   ABE|        ATL|       -2.0|
# |01031245|   -4|     602|   ABE|        ATL|       -2.0|
# |01030605|    0|     602|   ABE|        ATL|        2.0|
# |01041243|   10|     602|   ABE|        ATL|       12.0|
# |01040605|   28|     602|   ABE|        ATL|       30.0|
# |01051245|   88|     602|   ABE|        ATL|       90.0|
# |01050605|    9|     602|   ABE|        ATL|       11.0|
# |01061215|   -6|     602|   ABE|        ATL|       -4.0|
# |01061725|   69|     602|   ABE|        ATL|       71.0|
# |01061230|    0|     369|   ABE|        DTW|        2.0|
# |01060625|   -3|     602|   ABE|        ATL|       -1.0|
# |01070600|    0|     369|   ABE|        DTW|        2.0|
# |01071725|    0|     602|   ABE|        ATL|        2.0|
# |01071230|    0|     369|   ABE|        DTW|        2.0|
# |01070625|    0|     602|   ABE|        ATL|        2.0|
# |01071219|    0|     569|   ABE|        ORD|        2.0|
# |01080600|    0|     369|   ABE|        DTW|        2.0|
# +--------+-----+--------+------+-----------+-----------+
# only showing top 20 rows

# %%
# Preenchendo os dados missing com valor 0 apenas da coluna delay
df.na.fill(value=0,subset=['delay']).show()

# %%
# remove qualquer linha nula de qualquer coluna
df.na.drop().show()
# Out:
# +--------+-----+--------+------+-----------+-----------+
# |    date|delay|distance|origin|destination|Nova Coluna|
# +--------+-----+--------+------+-----------+-----------+
# |01011245|    6|     602|   ABE|        ATL|        8.0|
# |01020600|   -8|     369|   ABE|        DTW|       -6.0|
# |01021245|   -2|     602|   ABE|        ATL|        0.0|
# |01020605|   -4|     602|   ABE|        ATL|       -2.0|
# |01031245|   -4|     602|   ABE|        ATL|       -2.0|
# |01030605|    0|     602|   ABE|        ATL|        2.0|
# |01041243|   10|     602|   ABE|        ATL|       12.0|
# |01040605|   28|     602|   ABE|        ATL|       30.0|
# |01051245|   88|     602|   ABE|        ATL|       90.0|
# |01050605|    9|     602|   ABE|        ATL|       11.0|
# |01061215|   -6|     602|   ABE|        ATL|       -4.0|
# |01061725|   69|     602|   ABE|        ATL|       71.0|
# |01061230|    0|     369|   ABE|        DTW|        2.0|
# |01060625|   -3|     602|   ABE|        ATL|       -1.0|
# |01070600|    0|     369|   ABE|        DTW|        2.0|
# |01071725|    0|     602|   ABE|        ATL|        2.0|
# |01071230|    0|     369|   ABE|        DTW|        2.0|
# |01070625|    0|     602|   ABE|        ATL|        2.0|
# |01071219|    0|     569|   ABE|        ORD|        2.0|
# |01080600|    0|     369|   ABE|        DTW|        2.0|
# +--------+-----+--------+------+-----------+-----------+
# only showing top 20 rows
